# %% [markdown]
# # Título do Documento - utiliza-se 1"#"
#
# Nesta aula iremos aprender sobre como inserir ***markdowns*** dentro de arquivos do tipo **Jupyter Notebook**, utiliza-se clique duplo para editar o texto
#
# 2 "enter" para gerar parágrafo
#
#
# > ***Markdown*** é um tipo de document muito usado em ciências de dados e também para alimentar Inteligência Artificial.
# >
# > Manipular esse tipo de arquivo se torna fundamental para dominar as profissões do futuro que dependem de IAs.

# %% [markdown]
# ## Subtítulo de markdows utiliza-se 2 "#"
#
# o que diferencia um markdown de um notebook, é que no caso do notebook, ele também é capaz de ler códigos das linguagens de programação: *R*, *Julia* e *Python*.

# %% [markdown]
# ### Subtítulo de 3 nível - utiliza-se 3 "#"
# ### Linguagens de programação aceitas em notebooks
#
# - [x] Python
# - [x] Julia
# - [x] R
#
# ### Linguagens que iremos utilizar no curso:
#
# * [x] Python
# * [ ] Julia
# * [ ] R
